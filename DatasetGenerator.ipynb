# %% [markdown]
# <a href="https://colab.research.google.com/github/akshhack/TTS/blob/dev/DatasetGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup installs and requirements

# %%
# requirements 
# !pip3 install pytube youtube_transcript_api pydub pathlib uuid soundfile librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytube in /usr/local/lib/python3.7/dist-packages (12.1.0)
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.7/dist-packages (0.4.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: uuid in /usr/local/lib/python3.7/dist-packages (1.30)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (0.10.3.post1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from youtube_transcript_api) (2.23.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.4.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.56.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (4.12.0)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->youtube_transcript_api) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (4.1.1)

# %%
# python imports
import os, math, IPython, json, requests, shutil, enum, time, uuid, librosa
from IPython.display import Audio
from pathlib import Path

# pip imports
from pytube import YouTube
import soundfile as sf
from youtube_transcript_api import YouTubeTranscriptApi
from pydub import AudioSegment

# %% [markdown]
# # Youtube downloading

# %%
# youtube video downloader and .srt extractor
def download_yt_video_and_srt_file(video_id):
  try:
    print('Downloading video')
    yt = YouTube(f'https://www.youtube.com/watch?v={video_id}')
    ys = yt.streams.get_highest_resolution()
    ys.download()
    download_video_name = f'tmp.mp4'
    os.rename(ys.default_filename, download_video_name)
    print(f'Successfully downloaded file {download_video_name} to current directory')

    srt_list = YouTubeTranscriptApi.list_transcripts(video_id)
    srt = srt_list.find_transcript(['en', 'en-GB', 'en-US', 'en-IN'])

    if srt.is_generated: raise Exception('Transcription not accurate')
    print(f'Transcription is not generated: {srt.is_generated}')

    srt_dialogues = []
    for dialogue in srt.fetch():
      print(f'the dialogue is {dialogue}')
      srt_dialogues.append({
          'text': dialogue['text'].replace("\n", " "),
          'start': int(float(dialogue['start']) * 1000),
          'duration': int(float(dialogue['duration']) * 1000)
      })
    return srt_dialogues, None
  except Exception as e:
    print(f'Something went wrong. Error: {e}')
    return None, e

# %%
'''
Dolby background noise cleanup 
'''
DOLBY_APP_KEY = '3bHmxPox_SgvmflWCLesjw==' 
DOLBY_APP_SECRET = 'U7XSpthgyYvu3r3EXjblG1GrqC28PkpwCi0R3r8fbt4='

DOLBY_AUTH_TOKEN_URL = "https://api.dolby.io/v1/auth/token"
DOLBY_UPLOAD_URL = "https://api.dolby.com/media/input"
DOLBY_DOWNLOAD_URL = "https://api.dolby.com/media/output"
DOLBY_ENHANCE_URL = "https://api.dolby.com/media/enhance"

class DolbyJobStatuses(enum.Enum):
    PENDING = 'Pending'
    RUNNING = 'Running'
    SUCCESS = 'Success'
    FAILED = 'Failed'
    CANCELLED = 'Cancelled'
    INTERNAL_ERROR = 'InternalError'

logger_name = "[DOLBY]"

# get access token from keys.
def _generate_dolby_access_token():
    payload = { 'grant_type': 'client_credentials', 'expires_in': 1800 }
    response = requests.post(DOLBY_AUTH_TOKEN_URL, data=payload, auth=requests.auth.HTTPBasicAuth(DOLBY_APP_KEY, DOLBY_APP_SECRET))
    body = json.loads(response.content)
    return body['access_token']

# upload audio file to dolby temp store for processing 
# Set or replace these values
def _upload_to_dolby_temp_store(input_file_path: str, temp_dolby_path: str, access_token: str):
    # Declare dlb:// location
    headers = {
        "Authorization": "Bearer {0}".format(access_token),
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    body = {
        "url": temp_dolby_path,
    }

    response = requests.post(DOLBY_UPLOAD_URL, json=body, headers=headers)
    response.raise_for_status()
    data = response.json()
    presigned_url = data["url"]

    # Upload media
    print(f"{logger_name} Uploading {input_file_path} to {presigned_url}")
    with open(input_file_path, "rb") as input_file:
        requests.put(presigned_url, data=input_file)
    return None

def _download_file_from_dolby_temp_store(output_path: str, temp_dolby_path: str,  access_token: str):
    headers = {
        "Authorization": "Bearer {0}".format(access_token),
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    args = {
        "url": temp_dolby_path,
    }

    with requests.get(DOLBY_DOWNLOAD_URL, params=args, headers=headers, stream=True) as response:
        response.raise_for_status()
        response.raw.decode_content = True
        print(f"{logger_name} Downloading from {0} into {1}".format(response.url, output_path))
        # output_dir = get_file_directory(output_path)
        # create_directory_if_not_exist(output_dir)
        with open(output_path, "wb") as output_file:
            shutil.copyfileobj(response.raw, output_file)

def _check_job_status(job_URL: str, job_id: str, access_token: str) -> str:
    request_url = job_URL + f"?job_id={job_id}"
    print(f"{logger_name} Request URL for checking job status is {request_url}")

    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    response = requests.get(request_url, headers=headers)
    print(f"{logger_name} Response is {str(response.text)}")
    return response.json()['status']

def enhance_voice_from_dolby(input_file_path:str, output_path:str, access_token) -> str:
    payload = {
      "input" : input_file_path,
      "output": output_path,      # IT IS ALSO REQUIRED
      "content" : {
        "type": "voice_recording"
      },
      "audio": {
        "loudness": {
            "enable": True,
            "target_level": -18,
            "dialog_intelligence": True,
            "speech_threshold": 15,
            "peak_limit": -1,
            "peak_reference": "true_peak"
        },
        "dynamics": {"range_control": {
                "enable": True,
                "amount": "medium"
            }},
        "noise": {"reduction": {
                "enable": True,
                "amount": "high"
            }},
        "filter": {
            "dynamic_eq": {"enable": True},
            "high_pass": {
                "enable": True,
                "frequency": 80
            },
            "hum": {"enable": True}
        },
        "speech": {
            "isolation": {
                "enable": True,
                "amount": 100
            },
            "sibilance": {"reduction": {
                    "enable": True,
                    "amount": "medium"
                }},
            "plosive": {"reduction": {
                    "enable": True,
                    "amount": "medium"
                }},
            "click": {"reduction": {
                    "enable": False,
                    "amount": "medium"
                }}
        },
        "music": {"detection": {"enable": False}}
    }
    }

    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json",
        "Accept": "application/json"
    }

    response = requests.post(DOLBY_ENHANCE_URL, json=payload, headers=headers)
    print(f'Response is {response.json()}')
    return response.json()['job_id']

def get_enhanced_voice_from_dolby(input_file_path:str, output_path:str) -> str:

    access_token = _generate_dolby_access_token()

   # write input_path file to temporary storage in dolby (expires after 24 hours)
    input_file_name, input_file_name_extension = get_file_name_and_extension(input_file_path)
    temp_dolby_input_path = f"dlb://in/{input_file_name + input_file_name_extension}"
    print(f"{logger_name} Dolby path for input: {temp_dolby_input_path}")
    _upload_to_dolby_temp_store(input_file_path, temp_dolby_input_path, access_token)


    # process the uploaded input file using dolby analyze. 
    output_file_name, output_file_name_extension = get_file_name_and_extension(output_path)
    temp_dolby_output_path = f"dlb://out/{output_file_name + output_file_name_extension}"

    job_id = enhance_voice_from_dolby(temp_dolby_input_path, temp_dolby_output_path, access_token)

    # wait for analyze job to be finished (note that this is blocking)
    status = None 
    while (status == None or status == DolbyJobStatuses.PENDING.value or status == DolbyJobStatuses.RUNNING.value):
        time.sleep(1) # sleep for 1 second before checking again
        status =  _check_job_status(DOLBY_ENHANCE_URL, job_id, access_token)
        print(f"{logger_name} Status is {status}")
        if status == DolbyJobStatuses.FAILED.value or status == DolbyJobStatuses.CANCELLED.value or status == DolbyJobStatuses.INTERNAL_ERROR.value:
            return Exception(f"{logger_name} Something went wrong while processing the analyze request")
        elif status == DolbyJobStatuses.SUCCESS.value:
            break
        else:
            continue
    
    # now download the processed file and write 
    _download_file_from_dolby_temp_store(output_path, temp_dolby_output_path, access_token)
    return temp_dolby_output_path

def get_file_name_and_extension(file_path: str):
    """Returns the filename (without extension) and extension of file located at {file_path}

    Args:
        file_path (str): the file path of the file

    Returns:
        Tuple[str, str]: Returns a tuple of the file base name (without extension) and the file extension
    """
    path = Path(file_path)
    return path.with_suffix("").name, path.suffix

# %%
'''
Split clips 
'''
ROUND_SMOOTH_FACTOR = 200 # ms 
FADE_SMOOTH_FACTOR = 100 # ms
CLIP_LENGTH_FACTOR = 2

BASE_PATH='/content/drive/MyDrive/Camb.ai/Technology/Experiments/TTS/dataset/'

def round_down(x, base=ROUND_SMOOTH_FACTOR):
  return x - (x % base)
def round_up(x, base=ROUND_SMOOTH_FACTOR):
  return int(math.ceil(x / float(base))) * base

def split_audio_clips(video_id, srt_dialogues):
  audio = AudioSegment.from_file(f'tmp.mp4', "mp4")
  i = 0
  clip_num = 0
  dialogue_map = []
  while i < len(srt_dialogues) - CLIP_LENGTH_FACTOR:
    current_dialogue = srt_dialogues[i]
    next_dialogue = srt_dialogues[i+CLIP_LENGTH_FACTOR]

    dialogues = []
    j = i
    while j < i + CLIP_LENGTH_FACTOR: 
      dialogues.append(srt_dialogues[j]['text'])
      j += 1
    dialogue_text = ' '.join(dialogues).replace('\n', ' ')

    start = round_down(current_dialogue['start'], ROUND_SMOOTH_FACTOR)
    end = round_up(next_dialogue['start'], ROUND_SMOOTH_FACTOR)

    # save clipped
    uid = uuid.uuid4().hex
    audio_clip_output_file_name = f'{BASE_PATH}{uid}.wav'
    audio_clip = audio[start:end]
    audio_clip.export(audio_clip_output_file_name, format='wav')

    # trim silence using librosa
    y, sr = librosa.load(audio_clip_output_file_name)
    yt, index = librosa.effects.trim(y)
    sf.write(audio_clip_output_file_name, yt, 22050)

    # smooth out end and write back
    final_audio_clip = AudioSegment.from_file(audio_clip_output_file_name, "mp4")
    final_audio_clip = final_audio_clip.fade_in(FADE_SMOOTH_FACTOR).fade_out(FADE_SMOOTH_FACTOR)
    final_audio_clip.export(audio_clip_output_file_name, format='wav')

    dialogue_map.append({
        'uid': uid,
        'text': dialogue_text
    })

    i += CLIP_LENGTH_FACTOR
    clip_num += 1

  return dialogue_map

# %%
def dataset_generator(youtube_ids_file, output_metadata_file):
  dialogues = []
  with open(youtube_ids_file, 'r') as f:
    for id in f.readlines():
      try:
        # get youtube link downloaded
        srt_dialogues, err = download_yt_video_and_srt_file(id)
        if err is not None: raise err

        # remove background noise
        get_enhanced_voice_from_dolby("tmp.mp4", "tmp.mp4")
        
        # split and write the audio clips 
        dialogue_map = split_audio_clips(id, srt_dialogues)

        '''
        {
          'uid': uid,
          'text': dialogue_text
        }
        '''
        for entry in dialogue_map:
          print(entry)
          dialogues.append(f"{entry['uid']}|{entry['text']}|{entry['text'].lower()}\n")
      except Exception as e:
        print(f'Failed to process id {id} because {e}')
  
  with open(output_metadata_file, 'w') as f:
    f.writelines(dialogues)

# %%
youtube_ids_file = f'{BASE_PATH}/youtube_ids.txt'
output_metadata_file = f'{BASE_PATH}/metadata.csv'

# %%
dataset_generator(youtube_ids_file, output_metadata_file)
# Out:
# Downloading video
# Successfully downloaded file tmp.mp4 to current directory
# Transcription is not generated: False
# the dialogue is {'text': 'Namaskar\nYou listen to a song early in the morning', 'start': 0.7, 'duration': 5.009}
# the dialogue is {'text': 'and that plays in your head throughout the\nday. That is the power of morning. How you', 'start': 5.709, 'duration': 7.251}
# the dialogue is {'text': 'are going to end the day totally depends upon\nhow you start your day, but most of us begin', 'start': 12.96, 'duration': 8.59}
# the dialogue is {'text': 'the day totally in a wrong way. Here are a\nfew common morning mistakes that people do.', 'start': 21.55, 'duration': 7.49}
# the dialogue is {'text': 'First, staying in dark. Do not stay in dark\nfor long once you wake up, slide open your', 'start': 29.04, 'duration': 9.07}
# the dialogue is {'text': 'curtains and let the light fill your room.\nYour biological clock is light sensitive.', 'start': 38.11, 'duration': 7.59}
# the dialogue is {'text': 'For certain hormones to get you back into\nyour action, you need to have a bright and', 'start': 45.7, 'duration': 5.84}
# the dialogue is {'text': 'morning light. You must expose yourself to\nmorning light immediately after you wake up.', 'start': 51.54, 'duration': 7.11}
# the dialogue is {'text': 'Exposure to light in the morning and blue\ngreen light in particular prompts the release', 'start': 58.65, 'duration': 7.349}
# the dialogue is {'text': 'of hormone cortisol, which stimulates and\nwakes you up and inhibits the release of melatonin,', 'start': 65.999, 'duration': 7.33}
# the dialogue is {'text': 'which makes you feel drowsy. So, open your\nwindows, look up to bright blue sky and greenery', 'start': 73.329, 'duration': 8.011}
# the dialogue is {'text': 'around or go for a quick walk and come back.\nSecond mistake, which we do is missing our', 'start': 81.34, 'duration': 8.4}
# the dialogue is {'text': 'morning glass of warm water. Your body is\nin need of water after 7 8 hours of sleep.', 'start': 89.74, 'duration': 9.019}
# the dialogue is {'text': 'The first thing you should do after waking\nup is to drink a glass of warm water. It would', 'start': 98.759, 'duration': 7.17}
# the dialogue is {'text': 'rehydrate your body and also stimulates your\ndigestive system to action. Missing a glass', 'start': 105.929, 'duration': 6.86}
# the dialogue is {'text': 'of water can put stress on the system because\nof dehydration and also eating some solid', 'start': 112.789, 'duration': 7.62}
# the dialogue is {'text': 'food directly will again put lots of stress\nto your system. You must drink a glass of', 'start': 120.409, 'duration': 7.91}
# the dialogue is {'text': 'warm water the moment you wake up, but after\n15 minutes you can definitely take water with', 'start': 128.319, 'duration': 5.771}
# the dialogue is {'text': 'lemon, with little haldi inside, with little\nhoney inside. That would be beautiful. Third', 'start': 134.09, 'duration': 7.06}
# the dialogue is {'text': 'mistake we do is rushing to work. Being in\nhurry is a very big mistake which we do early', 'start': 141.15, 'duration': 7.509}
# the dialogue is {'text': 'in the morning and this restlessness will\ncontinue throughout the day. Your state of', 'start': 148.659, 'duration': 7.28}
# the dialogue is {'text': 'mind in morning can decide your energy and\nyour state of being for the whole day. Hence', 'start': 155.939, 'duration': 8.601}
# the dialogue is {'text': 'you plan your morning well in advance in previous\nnight so that you can at least spend one hour', 'start': 164.54, 'duration': 7.74}
# the dialogue is {'text': 'for yourself and practice Yoga, walking, meditation,\npranayama, etc and spending time with nature.', 'start': 172.28, 'duration': 10.98}
# the dialogue is {'text': "The calmness and focus will prevail throughout\nthe day's work. You will be energetic, more", 'start': 183.26, 'duration': 7.97}
# the dialogue is {'text': 'joyful and more peaceful. The fourth mistake,\nwhich we do early in the morning, is to check', 'start': 191.23, 'duration': 7.729}
# the dialogue is {'text': 'our mobile phone. 80% of smartphone users\ncheck their mobile phones within 15 minutes', 'start': 198.959, 'duration': 8.81}
# the dialogue is {'text': 'of waking up. This habit can disturb the peace\nof mind which you have attained through sleep.', 'start': 207.769, 'duration': 7.931}
# the dialogue is {'text': 'We are exposing ourselves to overload of information\nthe moment we wake up. This could cause more', 'start': 215.7, 'duration': 9.28}
# the dialogue is {'text': 'stress to your mind. Also, the exposure to\nbright light of phone can affect your eyes', 'start': 224.98, 'duration': 8.239}
# the dialogue is {'text': 'because of the darkness of the atmosphere.\nThe blue light of mobile phone can cause reddening', 'start': 233.219, 'duration': 6.69}
# the dialogue is {'text': 'of your eyes and dryness, so avoid using your\nphone at least for one hour after waking up.', 'start': 239.909, 'duration': 6.582}
# the dialogue is {'text': 'The fifth mistake that we do is skipping our\nbreakfast. Consuming more calorie early in', 'start': 246.491, 'duration': 9.339}
# the dialogue is {'text': 'the morning may reduce the risk of heart attack,\ndiabetes, and more circulatory problems. Skipping', 'start': 255.83, 'duration': 9.02}
# the dialogue is {'text': 'the breakfast can also make you eat more throughout\nthe day and also can put your system under', 'start': 264.85, 'duration': 7.33}
# the dialogue is {'text': 'stress. Your body has high absorbing capacity\nearly in the morning. Hence, having breakfast', 'start': 272.18, 'duration': 9.04}
# the dialogue is {'text': 'within two hours of waking up can help your\nbody absorb all the nutrients efficiently.', 'start': 281.22, 'duration': 7.51}
# the dialogue is {'text': "And don't forget to include proteins in every\nmeal including breakfast as protein is linked", 'start': 288.73, 'duration': 9.0}
# the dialogue is {'text': 'to having less body fat, but has lots of other\nbenefits. Greek yogurt and cottage cheese', 'start': 297.73, 'duration': 8.0}
# the dialogue is {'text': 'are very good source of breakfast protein.\nMorning makes a foundation of your day. Make', 'start': 305.73, 'duration': 8.77}
# the dialogue is {'text': 'sure that you build your foundation strong.\nAvoid all these silly mistakes which we do', 'start': 314.5, 'duration': 7.16}
# the dialogue is {'text': 'early in the morning and begin your day with\nhappiness and peace.', 'start': 321.66, 'duration': 6.0}
# the dialogue is {'text': 'Namaskar', 'start': 327.66, 'duration': 0.45}
# [DOLBY] Dolby path for input: dlb://in/tmp.mp4
# [DOLBY] Uploading tmp.mp4 to https://media-api-proxfyprug.s3-accelerate.amazonaws.com/5c0f7062-6eba-439d-9948-b8449eb6b176/in/tmp.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIA2N2ZL3VQLZR3PGZI%2F20220915%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20220915T163622Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEAaCXVzLXdlc3QtMiJHMEUCIQCDoZ2Zn%2F0YijpwShfSkWWMJCDEKbFyBXil2vE9tz6npgIgcuTa533gce9U9hzAZ9cMnson78ZWHel%2BOR8PBl9MXOEqlAMI2f%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARADGgw3MTY5MTAwOTE2MTYiDCsVHsNXeIKqM9XzIyroAmpl%2FsBpQO9bdpBa%2B9FwGS%2BOWbjidacRWpdFQ%2FfUXWAcSullsOgDUFGM1%2BGD%2BufE6pfeANA%2BCy0ef4yV559MaSEtzfGi6Ms7TGqc9avVnL%2FpdbQksM2i6%2B%2FXLSxvKjfLZkScn3U4%2Bd40%2BzW9r%2B7Zy6PyFWZuqgB5eZnmelVSrSvz8hXrRoqNuVeBY3oP%2BUXTVVNQ2oWj1Zt4bTNKKNx6shk6EUIFzduri%2Fv74abFMY%2BdSBgDUc%2BGmo5YzD46oc%2BKFm2r1CjNwH%2FTmZi2XIJZAJ0LMb0Kq0HqK%2FvKhK5S63xfApQ8ymsBn7nVxecQvZnIE4Am33N7bXFEDKZxPSVhpIshkhP6IXNVVHY8GgBKcTzBb0ZtAfF7f7em61w6UvQ4QCBF23o8%2BjYdxT%2FldnTUPSyhlQ2U%2BaNC07Au6QYxKD9gRX3yBKZKdKvA7pJPVDWZ1Fc3QZoz4u4e2%2BNvHvX1T6WI5Lhk%2Ftca7jDzmY2ZBjqdAebIYuhtdssbyU3%2BTxpnSHRPCosfETDem3uscg8D3%2BWO0tPIU%2B53%2FiSIREvaxZEz73kAck3%2BsswbL%2FhEZZKSwJfj1T7J7LXSZVistlVg0CeV9ZOAPcLSAb0RzCSLZdDQxeh1ed4RJAb7Gcpj4B%2FsNB8r9k8hIxzc7b4zhmq6aqqFhYhTQ%2FIlIgv6TGWzjRUmpw36w%2FSAUvexNhcyf14%3D&X-Amz-Signature=a1287b94675e1c300dedc3381efda304844acb1522d709a1524d7ad02971703f&X-Amz-SignedHeaders=host&x-id=PutObject
# Response is {'job_id': 'cfdec41d-56ee-442c-9953-f7da12b2bf63'}
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":0,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":38,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=cfdec41d-56ee-442c-9953-f7da12b2bf63
# [DOLBY] Response is {"path":"/media/enhance","status":"Success","progress":100,"api_version":"v1.1.2","result":{}}
# [DOLBY] Status is Success
# [DOLBY] Downloading from 0 into 1
# {'uid': 'a03fb959a2364039af313ec9dfa6adbf', 'text': 'Namaskar You listen to a song early in the morning and that plays in your head throughout the day. That is the power of morning. How you'}
# {'uid': 'd90a93ce50f24597a180f75481802c51', 'text': 'are going to end the day totally depends upon how you start your day, but most of us begin the day totally in a wrong way. Here are a few common morning mistakes that people do.'}
# {'uid': '496af1dbc13d47e3b2e009daa30a611e', 'text': 'First, staying in dark. Do not stay in dark for long once you wake up, slide open your curtains and let the light fill your room. Your biological clock is light sensitive.'}
# {'uid': '5bf45a699317493e81515f0abba75637', 'text': 'For certain hormones to get you back into your action, you need to have a bright and morning light. You must expose yourself to morning light immediately after you wake up.'}
# {'uid': '658b99179fe944aeaaf1311f0b923364', 'text': 'Exposure to light in the morning and blue green light in particular prompts the release of hormone cortisol, which stimulates and wakes you up and inhibits the release of melatonin,'}
# {'uid': '0a776dc1227f4b39965df53381a25f33', 'text': 'which makes you feel drowsy. So, open your windows, look up to bright blue sky and greenery around or go for a quick walk and come back. Second mistake, which we do is missing our'}
# {'uid': 'a841a52366c542398dc7e5bea469fb7b', 'text': 'morning glass of warm water. Your body is in need of water after 7 8 hours of sleep. The first thing you should do after waking up is to drink a glass of warm water. It would'}
# {'uid': 'c125ed3325a54d519cb00c65bdf0dcbf', 'text': 'rehydrate your body and also stimulates your digestive system to action. Missing a glass of water can put stress on the system because of dehydration and also eating some solid'}
# {'uid': 'b407e22017314c0f8ee7bcc3215856e8', 'text': 'food directly will again put lots of stress to your system. You must drink a glass of warm water the moment you wake up, but after 15 minutes you can definitely take water with'}
# {'uid': '55af905e7f5a455ca4959587182a2c5d', 'text': 'lemon, with little haldi inside, with little honey inside. That would be beautiful. Third mistake we do is rushing to work. Being in hurry is a very big mistake which we do early'}
# {'uid': '48c7de0bfc9543ca8a67947336cf320c', 'text': 'in the morning and this restlessness will continue throughout the day. Your state of mind in morning can decide your energy and your state of being for the whole day. Hence'}
# {'uid': '3e280bfb6aa04d25979a8f1e1dcd0036', 'text': 'you plan your morning well in advance in previous night so that you can at least spend one hour for yourself and practice Yoga, walking, meditation, pranayama, etc and spending time with nature.'}
# {'uid': 'e5f2ef05842f4de58bb8a9ca26c14439', 'text': "The calmness and focus will prevail throughout the day's work. You will be energetic, more joyful and more peaceful. The fourth mistake, which we do early in the morning, is to check"}
# {'uid': '0df853ea10a14f9b989e87ec4018aa58', 'text': 'our mobile phone. 80% of smartphone users check their mobile phones within 15 minutes of waking up. This habit can disturb the peace of mind which you have attained through sleep.'}
# {'uid': '0e172ee2f47e45e89d7a61673bde1686', 'text': 'We are exposing ourselves to overload of information the moment we wake up. This could cause more stress to your mind. Also, the exposure to bright light of phone can affect your eyes'}
# {'uid': '1ee170bef1d9481e930317fa4f097db1', 'text': 'because of the darkness of the atmosphere. The blue light of mobile phone can cause reddening of your eyes and dryness, so avoid using your phone at least for one hour after waking up.'}
# {'uid': '6b5167f05af84e2fbcd9073daf4e4b68', 'text': 'The fifth mistake that we do is skipping our breakfast. Consuming more calorie early in the morning may reduce the risk of heart attack, diabetes, and more circulatory problems. Skipping'}
# {'uid': '96fd4a290bd54e22ad2b8a3f2ffa2e35', 'text': 'the breakfast can also make you eat more throughout the day and also can put your system under stress. Your body has high absorbing capacity early in the morning. Hence, having breakfast'}
# {'uid': 'c472241bb59d4ecb89027c4f3910179f', 'text': "within two hours of waking up can help your body absorb all the nutrients efficiently. And don't forget to include proteins in every meal including breakfast as protein is linked"}
# {'uid': '696a97136df34833862351a38b6d0638', 'text': 'to having less body fat, but has lots of other benefits. Greek yogurt and cottage cheese are very good source of breakfast protein. Morning makes a foundation of your day. Make'}
# {'uid': '2347c31118c34bfd8794693f97cf925d', 'text': 'sure that you build your foundation strong. Avoid all these silly mistakes which we do early in the morning and begin your day with happiness and peace.'}
# Downloading video
# Successfully downloaded file tmp.mp4 to current directory
# Something went wrong. Error: Transcription not accurate
# Failed to process id h-Hrod2S1BQ
#  because Transcription not accurate
# Downloading video
# Successfully downloaded file tmp.mp4 to current directory
# Transcription is not generated: False
# the dialogue is {'text': 'Namaskar, in Mahabharat Saint Vyas says that\nI am shouting at the top of my voice with', 'start': 3.949, 'duration': 21.161}
# the dialogue is {'text': 'both arms raised that why you people are not\ndoing your duty by doing your duty you will', 'start': 25.11, 'duration': 7.87}
# the dialogue is {'text': 'get everything; name, fame, money, position\neverything that you want you will get by do', 'start': 32.98, 'duration': 7.31}
# the dialogue is {'text': 'your duty but nobody is listening to me and\nso this Mahabharat.', 'start': 40.29, 'duration': 7.58}
# the dialogue is {'text': 'What is this duty?', 'start': 47.87, 'duration': 2.29}
# the dialogue is {'text': 'This understanding of what is my duty is a\nvery big thing.', 'start': 50.16, 'duration': 3.18}
# the dialogue is {'text': 'We all are born.', 'start': 53.34, 'duration': 2.15}
# the dialogue is {'text': "We don't even know why we are born.", 'start': 55.49, 'duration': 3.06}
# the dialogue is {'text': 'What am I supposed to do after my birth?', 'start': 58.55, 'duration': 3.17}
# the dialogue is {'text': 'Here comes the answer, do your duty.', 'start': 61.72, 'duration': 4.609}
# the dialogue is {'text': 'I am going to show you three different ways\nin which we should understand this Dharma', 'start': 66.329, 'duration': 5.671}
# the dialogue is {'text': 'Bhava.', 'start': 72.0, 'duration': 1.0}
# the dialogue is {'text': 'Developed Dharma Bhava 2 hours jobs with confidence\nwhich Dharma Bhav.', 'start': 73.0, 'duration': 7.95}
# the dialogue is {'text': 'First, understand exactly what is our duty?', 'start': 80.95, 'duration': 6.79}
# the dialogue is {'text': 'What is my duty?', 'start': 87.74, 'duration': 1.15}
# the dialogue is {'text': 'Let me understand it really well here we talk\nabout the hierarchy of Duty which duty is', 'start': 88.89, 'duration': 7.109}
# the dialogue is {'text': 'First, Second, Third we should do very well.', 'start': 95.999, 'duration': 3.05}
# the dialogue is {'text': 'So the first duty, duty towards Self, second\nduty, duty towards near and dear with whom', 'start': 99.049, 'duration': 5.98}
# the dialogue is {'text': 'will live with whom we share our house.', 'start': 105.029, 'duration': 4.311}
# the dialogue is {'text': 'We have the duty towards that giving a quality\ntime understanding their problems trying to', 'start': 109.34, 'duration': 5.659}
# the dialogue is {'text': 'do whatever you can do and so on.', 'start': 114.999, 'duration': 2.98}
# the dialogue is {'text': 'Third duty towards work.', 'start': 117.979, 'duration': 2.57}
# the dialogue is {'text': 'At work, so many people are there to help\nyou to run the work you have a duty towards', 'start': 120.549, 'duration': 5.28}
# the dialogue is {'text': 'all of that everybody not just your colleagues,\nbut all others.', 'start': 125.829, 'duration': 5.461}
# the dialogue is {'text': 'Fourth duty towards a society where you live\npeople your neighbors, your area around you', 'start': 131.29, 'duration': 6.46}
# the dialogue is {'text': 'have a duty towards all that.', 'start': 137.75, 'duration': 2.27}
# the dialogue is {'text': 'Fifth, duty towards the nation where you live.', 'start': 140.02, 'duration': 3.109}
# the dialogue is {'text': 'You should follow the rules and regulations\nof the nation and so on.', 'start': 143.129, 'duration': 4.591}
# the dialogue is {'text': 'Six, duty towards humanity.', 'start': 147.72, 'duration': 4.129}
# the dialogue is {'text': 'Every human is your actually family vasudhaiva\nkutumbakam (वसुधैव कुटुम्बकम्)', 'start': 151.849, 'duration': 4.36}
# the dialogue is {'text': 'the whole world is your family and so you\nhave a duty towards every human.', 'start': 156.209, 'duration': 7.221}
# the dialogue is {'text': 'Now among all this usually we do follow certain\nthings but what I have noticed that we always', 'start': 163.43, 'duration': 8.789}
# the dialogue is {'text': "missed always don't give importance to his\na duty towards self.", 'start': 172.219, 'duration': 6.891}
# the dialogue is {'text': 'So understand duty towards Self is your first\nduty that means maintaining your balance all', 'start': 179.11, 'duration': 7.79}
# the dialogue is {'text': 'the time.', 'start': 186.9, 'duration': 4.74}
# the dialogue is {'text': 'The second thing, to make a schedule to follow\na proper timetable routine niyamas, when we', 'start': 191.64, 'duration': 11.22}
# the dialogue is {'text': 'follow such a systematic timetable we usually\nwill have the capacity to tolerate ups and', 'start': 202.86, 'duration': 6.739}
# the dialogue is {'text': 'down easily because we do what is coming next\nand we will be able to be prepared for it.', 'start': 209.599, 'duration': 7.321}
# the dialogue is {'text': 'So a sub systematic timetable is very much\nrequired.', 'start': 216.92, 'duration': 3.539}
# the dialogue is {'text': 'The third tip, follow yogic techniques which\nare design at The Yoga Institute so the first', 'start': 220.459, 'duration': 13.291}
# the dialogue is {'text': 'type of these techniques is all meditative\ntechnique sitting quietly in Sukhasan where', 'start': 233.75, 'duration': 6.999}
# the dialogue is {'text': 'you are sitting with your legs crossed back\nstraight head straight close your eyes relax', 'start': 240.749, 'duration': 7.6}
# the dialogue is {'text': 'your shoulders palm in words, and try to focus\nyour mind on your breath.', 'start': 248.349, 'duration': 8.45}
# the dialogue is {'text': "Don't interfere with your breath.", 'start': 256.799, 'duration': 1.901}
# the dialogue is {'text': 'Just focus your mind on your breath.', 'start': 258.7, 'duration': 2.55}
# the dialogue is {'text': 'And when you watch your breath no other thoughts\nwill come in your mind and mind would become', 'start': 261.25, 'duration': 5.11}
# the dialogue is {'text': 'calm.', 'start': 266.36, 'duration': 1.0}
# the dialogue is {'text': 'Certain asana where there is a slow breathing\nmovement with neuromuscular coordination sphere', 'start': 267.36, 'duration': 8.0}
# the dialogue is {'text': 'with a very focused.', 'start': 275.36, 'duration': 1.96}
# the dialogue is {'text': 'You have to start doing your movement with\nproper Yogendra Rhythm breathing Rhythm you', 'start': 277.32, 'duration': 8.19}
# the dialogue is {'text': 'do this Aasan and first among this could be\nTalasana.', 'start': 285.51, 'duration': 4.84}
# the dialogue is {'text': 'Both feet together keep one foot away from\neach other make them parallel to each other', 'start': 290.35, 'duration': 8.52}
# the dialogue is {'text': 'stand straight and while inhaling raise your\nright hand up right up above your head and', 'start': 298.87, 'duration': 7.67}
# the dialogue is {'text': 'stretch your body upwards be on the toe to\nsay that for some time you have taken a long', 'start': 306.54, 'duration': 6.29}
# the dialogue is {'text': 'breath along with your mind is really for\nplastic chair and rotate your arms and come', 'start': 312.83, 'duration': 7.36}
# the dialogue is {'text': 'back to the normal position.', 'start': 320.19, 'duration': 2.05}
# the dialogue is {'text': 'So this does it with other hand duets with\nboth the hands and this is one very strong', 'start': 322.24, 'duration': 5.54}
# the dialogue is {'text': 'technique to bring my the balance date your\nbody and mind this synchronize with each other.', 'start': 327.78, 'duration': 7.99}
# the dialogue is {'text': "So that's how we should go about now in life\nand slowly developed the concept of Dharma,", 'start': 335.77, 'duration': 7.63}
# the dialogue is {'text': 'the concept of Duty slowly see that we stop\ndoing Adharma in life and live life successfully', 'start': 343.4, 'duration': 8.62}
# the dialogue is {'text': "to see that we just don't contribute to ourselves\nonly but Dharma is usually for others so we", 'start': 352.02, 'duration': 9.08}
# the dialogue is {'text': 'contribute ourselves to others to family to\nsociety to decide to humanity and the whole', 'start': 361.1, 'duration': 7.16}
# the dialogue is {'text': 'world.', 'start': 368.26, 'duration': 1.0}
# the dialogue is {'text': "So that's how we should go about in life and\nstay tuned for our next episode on Jnana Bhav.", 'start': 369.26, 'duration': 7.73}
# the dialogue is {'text': 'Go on doing your Dharm and do your Dharma\nwell, and now understand what is the next', 'start': 376.99, 'duration': 5.98}
# the dialogue is {'text': 'power and that would be Jnana Bhawa till then.', 'start': 382.97, 'duration': 4.09}
# the dialogue is {'text': 'Namaskar.', 'start': 387.06, 'duration': 0.51}
# [DOLBY] Dolby path for input: dlb://in/tmp.mp4
# [DOLBY] Uploading tmp.mp4 to https://media-api-proxfyprug.s3-accelerate.amazonaws.com/5c0f7062-6eba-439d-9948-b8449eb6b176/in/tmp.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIA2N2ZL3VQLZR3PGZI%2F20220915%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20220915T163818Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEAaCXVzLXdlc3QtMiJHMEUCIQCDoZ2Zn%2F0YijpwShfSkWWMJCDEKbFyBXil2vE9tz6npgIgcuTa533gce9U9hzAZ9cMnson78ZWHel%2BOR8PBl9MXOEqlAMI2f%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARADGgw3MTY5MTAwOTE2MTYiDCsVHsNXeIKqM9XzIyroAmpl%2FsBpQO9bdpBa%2B9FwGS%2BOWbjidacRWpdFQ%2FfUXWAcSullsOgDUFGM1%2BGD%2BufE6pfeANA%2BCy0ef4yV559MaSEtzfGi6Ms7TGqc9avVnL%2FpdbQksM2i6%2B%2FXLSxvKjfLZkScn3U4%2Bd40%2BzW9r%2B7Zy6PyFWZuqgB5eZnmelVSrSvz8hXrRoqNuVeBY3oP%2BUXTVVNQ2oWj1Zt4bTNKKNx6shk6EUIFzduri%2Fv74abFMY%2BdSBgDUc%2BGmo5YzD46oc%2BKFm2r1CjNwH%2FTmZi2XIJZAJ0LMb0Kq0HqK%2FvKhK5S63xfApQ8ymsBn7nVxecQvZnIE4Am33N7bXFEDKZxPSVhpIshkhP6IXNVVHY8GgBKcTzBb0ZtAfF7f7em61w6UvQ4QCBF23o8%2BjYdxT%2FldnTUPSyhlQ2U%2BaNC07Au6QYxKD9gRX3yBKZKdKvA7pJPVDWZ1Fc3QZoz4u4e2%2BNvHvX1T6WI5Lhk%2Ftca7jDzmY2ZBjqdAebIYuhtdssbyU3%2BTxpnSHRPCosfETDem3uscg8D3%2BWO0tPIU%2B53%2FiSIREvaxZEz73kAck3%2BsswbL%2FhEZZKSwJfj1T7J7LXSZVistlVg0CeV9ZOAPcLSAb0RzCSLZdDQxeh1ed4RJAb7Gcpj4B%2FsNB8r9k8hIxzc7b4zhmq6aqqFhYhTQ%2FIlIgv6TGWzjRUmpw36w%2FSAUvexNhcyf14%3D&X-Amz-Signature=217704abfd63e049fba9a539eafc516dc42b0aeb472c7b89c0eadf1a1161ecd3&X-Amz-SignedHeaders=host&x-id=PutObject
# Response is {'job_id': 'f33f1320-d5c2-4954-84bb-c8fd7d0e3e90'}
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":0,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":3,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":19,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":46,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Running","progress":62,"api_version":"v1.1.2"}
# [DOLBY] Status is Running
# [DOLBY] Request URL for checking job status is https://api.dolby.com/media/enhance?job_id=f33f1320-d5c2-4954-84bb-c8fd7d0e3e90
# [DOLBY] Response is {"path":"/media/enhance","status":"Success","progress":100,"api_version":"v1.1.2","result":{}}
# [DOLBY] Status is Success
# [DOLBY] Downloading from 0 into 1
